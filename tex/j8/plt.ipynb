# %%
import matplotlib.pyplot as plt
import numpy as np
x_data = [341, 330, 290, 1261, 10231, 20470, 40839, 81968]
y_data = [0.002, 0.002, 0.002, 0.002, 0.010, 0.022, 0.059, 0.124]

x_2 = [1261, 10231, 20470, 40839, 81968]
y_2 = [0.002, 0.010, 0.022, 0.059, 0.124]

p = np.polyfit(x_data, y_data, 1)
f = np.poly1d(p)
print(f)
print(f(3800))
# plt.plot(x_data, np.polyval(p, x_data), 'r-')
plt.xlabel("Number of edges")
plt.ylabel("Time (s)")
plt.scatter(x_data, y_data)
# Out:
#
# 1.495e-06 x - 0.00122
# 0.004459232426886627
